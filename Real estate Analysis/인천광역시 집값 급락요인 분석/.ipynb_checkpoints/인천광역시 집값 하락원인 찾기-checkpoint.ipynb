# %%
# 모듈, 경로 설정
import pandas as pd
import pydeck as pdk
import geopandas as gpda
import config
import json
import requests
import sys
import folium
import warnings

warnings.filterwarnings(action='ignore')

path = "C:\github/aide-analysis/"
sys.path.append(path)

path2 = "C:\github/prop-tech/"
sys.path.append(path2)
from src.bigquery import bigquery_client, bigquery
from src.visualization import Pydeck
pydeck = Pydeck()
bq = bigquery_client
from core.config import Config
config = Config()

from mapboxgl.viz import *
from mapboxgl.utils import create_color_stops

# %%
# 시각화 한글패치
import os
import matplotlib.pyplot as plt

if os.name =='posix':

    plt.rc('font', family = 'AppleGothic')

else:

    plt.rc('font', family = 'Malgun Gothic')

# %% [markdown]
# ## 매매/전세 증감 확인

# %%
# 매매증감
from src.sql import DatabaseHandler
db = DatabaseHandler()
sql = f"""
SELECT *
FROM aide.kb_weekly_trading_change_rate
WHERE sigunguCode = '28000'
"""
trading = db.read_table(sql)

# 전세증감
from src.sql import DatabaseHandler
db = DatabaseHandler()
sql = f"""
SELECT *
FROM aide.kb_weekly_jeonse_change_rate
WHERE sigunguCode = '28000'
"""
rent = db.read_table(sql)

# 매매, 전세 증감 데이터 합치기
df = pd.merge(trading[['date','tradingChangeRate']], rent[['date', 'jeonseChangeRate']], on = 'date', how = 'inner')

# %%
# 1월10일 이후 추가된 데이터 보간
date_lst = pd.date_range('2022-01-17', '2022-05-30', freq = '7d')
plus_data = pd.DataFrame(date_lst)
plus_data['tradingChangeRate'] = [0.07,0.09,'', 0.08,0.03,0.04,0.01,-0.01,0.01,0.00,0.03,0.04,0.04,0.07,0.06,0.06,0.06,0.01,-0.08,-0.07]
plus_data['jeonseChangeRate'] = [0.05,0.08,'',0.05,0.01,0.07,0.03,0.03,0.02,0.05,0.08,0.04,0.09,0.09,0.10,0.08,0.07,0.03,-0.04,-0.05]
plus_data = plus_data.rename(columns= {0:'date'})
# # 원 데이터와 concat
df = pd.concat([df, plus_data], axis = 0, ignore_index=True)
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.drop(index = 697)

# %%
fig, ax = plt.subplots(figsize = (12,5))
# 매매, 전세 증감율
ax.plot(df['date'], df['tradingChangeRate'],label = '매매증감',color = 'blue')
ax.plot(df['date'], df['jeonseChangeRate'],label = '전세증감',color = 'gray')


# 그리드 추가
ax.grid(axis="y", c="lightgray") # "axis = 'x'" 는 x축 세로선 grid생성

# 필요없는 선 제거
ax.spines[["left", "top", "right"]].set_visible(False)

ax.legend()

# %% [markdown]
# ### 날짜 구간 확대

# %%
# 날짜 구간 확대
df['date'] = pd.to_datetime(df['date'])
df = df[df['date']>='2020-06']

# 2월8일 1개의 결측값 ffill로 보간
df = df.fillna(method='ffill')

# %%
# 시각화
from matplotlib.ticker import MaxNLocator

fig, ax = plt.subplots(figsize = (14,5))
# 매매, 전세 증감율
ax.plot(df['date'], df['tradingChangeRate'],label = '매매증감', color = 'b', alpha = 0.7,linewidth = 2)
ax.plot(df['date'], df['jeonseChangeRate'],label = '전세증감', color = 'gray', alpha = 0.7,linewidth = 2)


# 그리드 추가
ax.grid(axis="y", c="lightgray") # "axis = 'x'" 는 x축 세로선 grid생성

# xticks개수 조절
ax.xaxis.set_major_locator(MaxNLocator(18)) 

# 필요없는 선 제거
ax.spines[["left", "top", "right"]].set_visible(False)

ax.legend()

plt.xticks(rotation = 45)
# Out:
# (array([18350., 18400., 18450., 18500., 18550., 18600., 18650., 18700.,
#         18750., 18800., 18850., 18900., 18950., 19000., 19050., 19100.,
#         19150., 19200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# 인사이트 : 21년 초부터 오르기 시작하여 8월에 최고점을 찍고 이후 하락을 하는 모습

# %% [markdown]
# ## 공급양, 미분양

# %%
# 공급양
sql = f"""
SELECT  main.builtYear, SUM(sedaeCount) AS sedaeCount
FROM aide.apartment_danji_information AS main
WHERE main.builtYear >=2018
GROUP BY main.builtYear
ORDER BY builtYear
"""
supply2 = BH.read_table(sql)

# 미분양
sql = f"""
SELECT *
FROM aide.unsold_sigungu
WHERE sigunguCode = '28000' AND year >=2018
"""
unsold = db.read_table(sql)
unsold = pd.DataFrame(unsold.groupby('year')['unsold'].sum()).reset_index()

# merge
new = pd.merge(supply2, unsold , left_on = 'builtYear', right_on = 'year', how = 'left')

# %%
# viz
fig, ax = plt.subplots(figsize = (12, 5))
ax.bar(new['builtYear'], new['sedaeCount'], label = '공급양', color = 'gray', alpha =0.2)

ax2= ax.twinx()
ax2.bar(new['builtYear'], new['unsold'], label = '미분양', color = 'blue', alpha = 0.2)

# add grid
ax.grid(axis="y", c="lightgray") # "axis = 'x'" 는 x축 세로선 grid생성

# drop line
ax.spines[["left", "top", "right"]].set_visible(False)
ax2.spines[["left", "top", "right"]].set_visible(False)

# legend handles
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

# show legend
ax2.legend(lines+lines2, labels+labels2, loc ='upper right')

# %%
# 미분양
sql = f"""
SELECT *
FROM aide.unsold_sigungu
WHERE sigunguCode = '28000' AND ((year = 2021 and month >= 10) OR (year =2022 ))
"""
unsold = db.read_table(sql)
unsold['date'] = pd.to_datetime(unsold['date']).dt.strftime('%Y-%m')

# %%
fig,ax = plt.subplots(figsize = (12,5))

ax.bar(supply['date'], supply['sedaeCount'],color = 'blue', label = '공급양', alpha = 0.3)
ax2 = ax.twinx()
ax2.plot(unsold['date'],unsold['unsold'],color = 'gray', label = '미분양',linestyle ='--')

ax.legend()
ax2.legend(loc='upper left')
plt.show()

# %% [markdown]
# 인사이트 : 19년도에 많던 미분양이 20년도와 21년도에 걸쳐 급격하게 감소하고 공급량또한 많이 줄었다 이것이 21년도 전세,매매가격 증가에 영향이 있을것이라고 추정, 하지만 22년도 2월에 2000세대 이상의 공급과 함께 3월에 미분양 급증한것이 다시 하락으로 전환되는데 영향을 미친것임을 추정

# %% [markdown]
# ## 전세수급지수

# %%
jeonse = plt.imread('./전세수급지수.png')
plt.imshow(jeonse)

# %% [markdown]
# ## 매수우위지수

# %%
buysell = plt.imread('./매수우위지수.png')
plt.imshow(buysell)
