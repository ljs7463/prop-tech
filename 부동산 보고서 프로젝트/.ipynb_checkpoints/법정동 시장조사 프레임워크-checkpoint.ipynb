# %%
# 경로설정
import sys
path = "C:\github/aide-analysis/"
path2 = 'C:\github/aide-analysis/notebook/temp_ljs/Develop/지주리포트Lite/실거래 이상값 제거 연구 및 추론/모듈 및 압축파일 보관 폴더'
sys.path.append(path)
sys.path.append(path2)

import os
import sys
from pathlib import Path
sys.path.append(str(Path(os.getcwd())))
# 한글폰트
import os
import matplotlib.pyplot as plt
if os.name =='posix':
    plt.rc('font',family = 'ApplGothic')
else:
    plt.rc('font',family = 'Malgun Gothic')
    
# 경고출력문 제거
import warnings
warnings.filterwarnings("ignore")

# 모듈 import
import pandas as pd
import src
from src.openapi import KakaoLocalAPI as kakao
from openpyxl import load_workbook
from src.utils import insert_dataframe_to_excel_sheet
from src.sql import DatabaseHandler
from src.temp import *
from datetime import datetime
import datetime
from dateutil.relativedelta import relativedelta
from src.bigquery import BigqueryHandler
import seaborn as sns
import numpy as np
import statistics
from tqdm import tqdm
import config
from core.config import Config
import json
from datetime import datetime
import geopandas as gpd
from tqdm import tqdm
import folium
from src.bigquery import bigquery_client, bigquery
import geopandas as gpd
from shapely import wkt
from openpyxl import load_workbook
from src.utils import insert_dataframe_to_excel_sheet
from openpyxl.utils.dataframe import dataframe_to_rows
from difflib import SequenceMatcher
import openpyxl
import math
from dataclasses import dataclass
config = Config()
BH = BigqueryHandler()


# DataFrame 디스플레이 설정
pd.set_option('display.max_columns', 250)
pd.set_option('display.max_rows', 250)
pd.set_option('display.width', 100)

# %% [markdown]
# # 거래량

# %%
docs = kakao.search_address('서울특별시 동대문구 휘경동 179-84')

# %%
bdongCode = docs['documents'][0]['address']['b_code']
sigunguCode = docs['documents'][0]['address']['b_code'][:5]
sidoCode = docs['documents'][0]['address']['b_code'][:2]

# %%
sql = f"""
SELECT danji.complexNo,
       danji.sidoCode,
       danji.sigunguCode,
       danji.bdongCode,
       danji.complexName,
       danji.realEstateTypeCode,
       danji.isJsbh,
       danji.isDsh,
       danji.isShsb,
       danji.sigunguName,
       danji.bdongName,
       danji.totalHouseholdCount,
       danji.useApproveYear,
       danji.latitude,
       danji.longitude,
       danji.point,
       area.areaSixGroupNo,
       area.pyeongNo,
       area.jeonyongArea,
       area.jeonyongPyeong,
       area.supplyArea,
       area.supplyPyeong,
       price.tradeType,
       price.tradeYear,
       price.tradeMonth,
       price.contractDate,
       price.dealPrice,
       price.leasePrice,
       price.rentPrice,
       CAST(concat(price.tradeYear, '-',lpad(CAST(tradeMonth AS STRING),2,'0'),'-',"01") AS string) AS yearMonth
FROM `aidepartners.aide.complex_danji_information` AS danji
LEFT JOIN (SELECT complexNo,
                  areaSixGroupNo,
                  pyeongNo,
                  jeonyongArea,
                  jeonyongPyeong,
                  supplyArea,
                  supplyPyeong
           FROM `aidepartners.aide.complex_area_information_prod`
        ) AS area ON danji.complexNo = area.complexNo
LEFT JOIN (SELECT complexNo,
                  areaNo,
                  tradeType,
                  tradeYear,
                  tradeMonth,
                  contractDate,
                  dealPrice,
                  leasePrice,
                  rentPrice,
                  
           FROM `aidepartners.aide.complex_real_price_prod`
           ) AS price  ON area.complexNo = price.complexNo
                       AND area.pyeongNo = price.areaNo
WHERE danji.sidoCode = "{sidoCode}" 
      AND realEstateTypeCode IN ('APT',"ABYG") 
      AND totalHouseholdCount >100
"""
df = BH.read_table(sql)

# %%
df
# Out:
#         complexNo sidoCode sigunguCode   bdongCode      complexName realEstateTypeCode  isJsbh  \
# 0          143727       11       11140  1114013600     힐스테이트남산(도시형)               ABYG   False
# 1          118738       11       11200  1120011400  아크로서울포레스트(주상복합)                APT    True
# 2           27803       11       11110  1111018300         평창롯데캐슬로잔                APT   False
# 3           27803       11       11110  1111018300         평창롯데캐슬로잔                APT   False
# 4           27803       11       11110  1111018300         평창롯데캐슬로잔                APT   False
# ...           ...      ...         ...         ...              ...                ...     ...
# 2723933     27475       11       11740  1174011000        강일리버파크2단지                APT   False
# 2723934     27475       11       11740  1174011000        강일리버파크2단지                APT   False
# 2723935     27475       11       11740  1174011000        강일리버파크2단지                APT   False
# 2723936     27475       11       11740  1174011000        강일리버파크2단지                APT   False
# 2723937     27475       11       11740  1174011000        강일리버파크2단지                APT   False
#
#          isDsh  isShsb sigunguName bdongName  totalHouseholdCount useApproveYear   latitude  \
# 0         True   False      서울시 중구       묵정동                  282           2024  37.561738
# 1        False   False     서울시 성동구     성수동1가                  280           2020  37.544170
# 2        False   False     서울시 종로구       평창동                  112           2009  37.610228
# 3        False   False     서울시 종로구       평창동                  112           2009  37.610228
# 4        False   False     서울시 종로구       평창동                  112           2009  37.610228
# ...        ...     ...         ...       ...                  ...            ...        ...
# 2723933  False   False     서울시 강동구       강일동                  442           2009  37.569339
# 2723934  False   False     서울시 강동구       강일동                  442           2009  37.569339
# 2723935  False   False     서울시 강동구       강일동                  442           2009  37.569339
# 2723936  False   False     서울시 강동구       강일동                  442           2009  37.569339
# 2723937  False   False     서울시 강동구       강일동                  442           2009  37.569339
#
#           longitude                        point areaSixGroupNo pyeongNo  jeonyongArea  \
# 0        126.999300    POINT(126.9993 37.561738)             A0        2         27.71
# 1        127.043354   POINT(127.043354 37.54417)             A5       25        200.70
# 2        126.977354  POINT(126.977354 37.610228)             A5        6        215.05
# 3        126.977354  POINT(126.977354 37.610228)             A5        6        215.05
# 4        126.977354  POINT(126.977354 37.610228)             A5        6        215.05
# ...             ...                          ...            ...      ...           ...
# 2723933  127.176727  POINT(127.176727 37.569339)             A3        2         84.53
# 2723934  127.176727  POINT(127.176727 37.569339)             A3        2         84.53
# 2723935  127.176727  POINT(127.176727 37.569339)             A3        2         84.53
# 2723936  127.176727  POINT(127.176727 37.569339)             A3        2         84.53
# 2723937  127.176727  POINT(127.176727 37.569339)             A3        2         84.53
#
#          jeonyongPyeong  supplyArea  supplyPyeong tradeType  tradeYear  tradeMonth contractDate  \
# 0                  8.38       40.71         12.31      None       <NA>        <NA>          NaT
# 1                 60.71      251.73         76.14      None       <NA>        <NA>          NaT
# 2                 65.05      248.46         75.15        A1       2012          11   2012-11-19
# 3                 65.05      248.46         75.15        A1       2012          10   2012-10-16
# 4                 65.05      248.46         75.15        A1       2012          10   2012-10-26
# ...                 ...         ...           ...       ...        ...         ...          ...
# 2723933           25.57      111.05         33.59        A1       2017           9   2017-09-16
# 2723934           25.57      111.05         33.59        B2       2017           9   2017-09-19
# 2723935           25.57      111.05         33.59        B1       2015           7   2015-07-21
# 2723936           25.57      111.05         33.59        A1       2015           4   2015-04-07
# 2723937           25.57      111.05         33.59        A1       2020          11   2020-11-05
#
#          dealPrice  leasePrice  rentPrice   yearMonth
# 0             <NA>        <NA>       <NA>        None
# 1             <NA>        <NA>       <NA>        None
# 2           141576        <NA>       <NA>  2012-11-01
# 3           137000        <NA>       <NA>  2012-10-01
# 4           145000        <NA>       <NA>  2012-10-01
# ...            ...         ...        ...         ...
# 2723933      54000        <NA>       <NA>  2017-09-01
# 2723934       <NA>       37000         18  2017-09-01
# 2723935       <NA>       37000          0  2015-07-01
# 2723936      43000        <NA>       <NA>  2015-04-01
# 2723937      92700        <NA>       <NA>  2020-11-01
#
# [2723938 rows x 30 columns]

# %%
data = df[-df['tradeYear'].isna()].reset_index(drop =True)

# %%
data_new = data.groupby(['yearMonth'])['complexNo'].count().reset_index()

# %%
sns.lineplot(data_new['yearMonth'], data_new['complexNo'])
# Out:
# <AxesSubplot:xlabel='yearMonth', ylabel='complexNo'>

# %%
sql =f"""
SELECT price.* ,
       ST_DISTANCE(st_geogpoint({lon}, {lat}),st_geogpoint(longitude,latitude),FALSE) AS distance
FROM `aidepartners.aide.complex_danji_information` AS danji
LEFT JOIN (
    SELECT complexNo, 
           complexName,
           totalHouseholdCount,
           supplyArea,
           jeonyongArea, 
           areaSixGroupNo,
           dealPrice,
           pricePerSupplyPyeong,
           averagePyeong,
           yearMonth
    FROM `aidepartners.aide.aide_apartment_price_origin`
    WHERE yearMonth >='2020-01-01' 
          AND tradeType = 'A1'
          AND (isReal = True OR predict = True)
    ) AS price ON danji.complexNo = price.complexNo
WHERE danji.sidoCode = '11' 
      AND ST_DISTANCE(st_geogpoint({lon}, {lat}),st_geogpoint(longitude,latitude),FALSE) <=1500
      AND danji.realEstateTypeCode IN ('APT','ABYG')
ORDER BY distance

"""
df = BH.read_table(sql)

# %% [markdown]
# # 1. 유사단지

# %% [markdown]
# 유사단지 찾는 로직 없기때문에 일단은 면적별/ 세대수별/ 가격별로 비교

# %% [markdown]
# ### 면적

# %%
df[(df['areaSixGroupNo']=='A1')&(df['totalHouseholdCount']>=100)].sort_values(by = 'distance')
# Out:
#      complexNo        complexName  totalHouseholdCount  supplyArea  jeonyongArea areaSixGroupNo  \
# 232       8749               휘경동양                  282       61.13         43.59             A1
# 285     103167  회기역한일베라체캠퍼스(주상복합)                  264       67.77         46.15             A1
# 288     103167  회기역한일베라체캠퍼스(주상복합)                  264       64.62         43.16             A1
# 295     103167  회기역한일베라체캠퍼스(주상복합)                  264       36.49         24.31             A1
# 1104  388000000              21052632   2.083559e+07  2020-09-01  1282.921169
# 1117  304000000              16494845   1.669333e+07  2020-02-01  1282.921169
# 1116  362000000              18844352   1.745911e+07  2020-03-01  1282.921169
# 1113  370000000              20075963   2.007197e+07  2020-07-01  1282.921169
# 1112  300000000              15616866   1.669333e+07  2020-02-01  1282.921169
# 1111  420000000              28727770   2.814247e+07  2021-08-01  1282.921169
# 1107  270000000              18467852   1.819149e+07  2020-06-01  1282.921169
# 1106  328000000              22435021   2.179031e+07  2020-10-01  1282.921169
# 1105  400000000              21703744   2.179031e+07  2020-10-01  1282.921169
# 1081  353000000              19153554   1.819149e+07  2020-06-01  1282.921169
# 1102  235000000              16073871   1.745911e+07  2020-03-01  1282.921169
# 1099  377000000              20455779   2.045280e+07  2020-08-01  1282.921169
# 1096  270000000              18467852   1.669333e+07  2020-02-01  1282.921169
# 1094  235000000              16073871   1.819149e+07  2020-06-01  1282.921169
# 1093  338000000              23119015   2.315504e+07  2021-01-01  1282.921169
# 1091  405000000              21975041   2.179031e+07  2020-10-01  1282.921169
# 1089  237500000              16244870   1.669333e+07  2020-02-01  1282.921169
# 1088  445000000              24145415   2.229836e+07  2020-12-01  1282.921169
# 1087  285000000              15463918   1.556972e+07  2020-01-01  1282.921169
# 1086  360000000              19533370   1.887652e+07  2020-04-01  1282.921169
# 1085  385000000              20889853   2.179031e+07  2020-10-01  1282.921169
# 1084  360000000              18740239   2.007197e+07  2020-07-01  1282.921169
# 1098  380000000              20618557   2.083559e+07  2020-09-01  1282.921169
# 1582  248000000              14814815   1.481482e+07  2021-06-01  1469.061339
# 1578  238000000              14217443   1.421744e+07  2022-01-01  1469.061339
# 1584  240000000              14336918   1.433692e+07  2023-02-01  1469.061339
# 1568  235000000              14038232   1.403823e+07  2023-01-01  1469.061339
# 1567  230000000              13739546   1.373955e+07  2020-06-01  1469.061339
# 1572  237000000              14031972   1.403197e+07  2022-09-01  1469.061339
# 1586       <NA>                  <NA>   1.433692e+07  2023-03-01  1469.061339

# %%
sql =f"""
SELECT price.*, danji
FROM `aidepartners.aide.aide_apartment_price_origin` AS price
LEFT JOIN (
    SELECT complexNo, longitude, latitude
    FROM `aidepartners.aide.complex_danji_information`
)AS danji ON price.complexNo = danji.complexNo
"""

# %%
# sql = f"""
# SELECT area.*, danji.longitude, danji.latitude,danji.useApproveYear, danji.totalHouseholdCount
# FROM `aidepartners.aide.complex_area_information_prod` AS area
# LEFT JOIN (SELECT complexNo, longitude, latitude, useApproveYear, totalHouseholdCount FROM `aidepartners.aide.complex_danji_information`) AS danji ON area.complexNo = danji.complexNo
# WHERE ST_DISTANCE(st_geogpoint({lon},{lat}), st_geogpoint(danji.longitude,danji.latitude),False)<=2000 and realEstateTypeCode IN ('APT','ABYG') AND area.areaSixGroupNo IN ("A0","A1")
# """
# df = BH.read_table(sql)

# %%
sql = f"""
SELECT area.*, danji.longitude,danji.sigunguCode, danji.bdongCode,  danji.latitude,danji.useApproveYear, danji.totalHouseholdCount,
       price.dealPrice, price.contractDate, (price.dealPrice*10000)/ area.supplyPyeong AS pricePerPyeong
FROM `aidepartners.aide.complex_area_information_prod` AS area
LEFT JOIN (SELECT complexNo, sigunguCode, bdongCode, longitude, latitude, useApproveYear, totalHouseholdCount FROM `aidepartners.aide.complex_danji_information`) AS danji ON area.complexNo = danji.complexNo
LEFT JOIN (SELECT complexNo, areaNo,dealPrice,contractDate  FROM `aidepartners.aide.complex_real_price_prod` WHERE tradeType = 'A1' AND contractDate >='2018-01-01') AS price ON area.complexNo = price.complexNo AND area.pyeongNo = price.areaNo
WHERE danji.sigunguCode = "{sigunguCode}" and realEstateTypeCode IN ('APT','ABYG') AND area.areaSixGroupNo IN ("A0","A1")

"""
df = BH.read_table(sql)

# %%
# 총세대수 100세대 이상
df = df[df['totalHouseholdCount']>=100].reset_index(drop =True)

# %%
# 필요한 컬럼 색인
df = df[['pnuCode','complexNo','complexName','useApproveYear','totalHouseholdCount','realEstateTypeCode','pyeongNo','supplyArea','jeonyongArea','householdCountByPyeong','jeonyongRate','areaSixGroupNo','entranceType','roomCount','bathroomCount','dealPrice','contractDate','pricePerPyeong']]

# %% [markdown]
# # 마포구 최근 5년내 건축된 단지들의 가격

# %%
df_recent = df[(df['jeonyongArea']>=30)&(df['useApproveYear']>="2018")]
a , b = df_recent.loc[-df_recent['dealPrice'].isna(),'complexNo'].unique()

# %%
df_a = df_recent[df_recent['complexNo']==a]
df_b = df_recent[df_recent['complexNo']==b]

# %%
sns.scatterplot(df_a['contractDate'], df_a['pricePerPyeong'], label = df_a['complexName'].iloc[0])
sns.scatterplot(df_b['contractDate'], df_b['pricePerPyeong'], label = df_b['complexName'].iloc[0])

# y축 설정
current_values =plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# grid 설정
plt.grid(axis = "y", c = "lightgray")
plt.grid(axis = "x", c = "lightgray")
plt.legend()
plt.title('마포구 최근 5년내 건축된 단지 가격(휘경자이디센시아와 비슷한면적)')
# Out:
# Text(0.5, 1.0, '마포구 최근 5년내 건축된 단지 가격(휘경자이디센시아와 비슷한면적)')

# %%
df_recent = df[(df['jeonyongArea']>=30)&(df['totalHouseholdCount']>=200)]
for i in list(df_recent.loc[-df_recent['dealPrice'].isna(),'complexNo'].unique()):
    test =df_recent.loc[df_recent['complexNo']==i]
    name = test['complexName'].iloc[0]
    year = test['useApproveYear'].iloc[0]
    area = test['jeonyongArea'].iloc[0]
    sedae = test['totalHouseholdCount'].iloc[0]
    sns.scatterplot(test['contractDate'], test['pricePerPyeong'], label = test['complexName'].iloc[0])
    # y축 설정
    current_values =plt.gca().get_yticks()
    plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

    # grid 설정
    plt.grid(axis = "y", c = "lightgray")
    plt.grid(axis = "x", c = "lightgray")
    plt.legend()
    plt.title(f'{name}단지 / 전용면적 {area}/ 사용승인일 {year}, 세대수{sedae}')
    plt.savefig(f'{name}단지.png')
    
    # 각 단지별로 시각화 하기 위한 코드
    fig = plt.gcf()
    plt.close(fig)
