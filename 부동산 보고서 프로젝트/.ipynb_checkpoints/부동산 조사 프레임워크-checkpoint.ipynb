# %%
# !pip install pygwalker

# %%
import pygwalker as pyg

# %%
# 경로설정
import sys
path = "C:\github/aide-analysis/"
path2 = 'C:\github/aide-analysis/notebook/temp_ljs/Develop/지주리포트Lite/실거래 이상값 제거 연구 및 추론/모듈 및 압축파일 보관 폴더'
sys.path.append(path)
sys.path.append(path2)

import os
import sys
from pathlib import Path
sys.path.append(str(Path(os.getcwd())))
# 한글폰트
import os
import matplotlib.pyplot as plt
if os.name =='posix':
    plt.rc('font',family = 'ApplGothic')
else:
    plt.rc('font',family = 'Malgun Gothic')
    
# 경고출력문 제거
import warnings
warnings.filterwarnings("ignore")

# 모듈 import
import pandas as pd
import src
from src.openapi import KakaoLocalAPI as kakao
from openpyxl import load_workbook
from src.utils import insert_dataframe_to_excel_sheet
from src.sql import DatabaseHandler
from src.temp import *
from datetime import datetime
import datetime
from dateutil.relativedelta import relativedelta
from src.bigquery import BigqueryHandler
import seaborn as sns
import numpy as np
import statistics
from tqdm import tqdm
import config
from core.config import Config
import json
from datetime import datetime
import geopandas as gpd
from tqdm import tqdm
import folium
from src.bigquery import bigquery_client, bigquery
import geopandas as gpd
from shapely import wkt
from openpyxl import load_workbook
from src.utils import insert_dataframe_to_excel_sheet
from openpyxl.utils.dataframe import dataframe_to_rows
from difflib import SequenceMatcher
import openpyxl
import math
from 실거래전처리 import TradeProcessing
from dataclasses import dataclass
config = Config()
BH = BigqueryHandler()


# DataFrame 디스플레이 설정
pd.set_option('display.max_columns', 250)
pd.set_option('display.max_rows', 250)
pd.set_option('display.width', 100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 56>()
#      54 import openpyxl
#      55 import math
# ---> 56 from 실거래전처리 import TradeProcessing
#      57 from dataclasses import dataclass
#      58 config = Config()
#
# ModuleNotFoundError: No module named '실거래전처리'

# %% [markdown]
# # 지난달(23년01월)대비 이번달(23년02월) 매매가격이 떨어진 단지 찾기

# %% [markdown]
# - 타입별로 특수성이 있을 수 있기때문에 areaSixGroupNo 대신 pyeongNo를 기준으로 동 타입기준으로 가격비교 하기 -> 이렇게 했을때 문제가 없을지도 검증이 필요하다

# %%
# sql = f"""

# SELECT sigunguCode
# FROM `aidepartners.aide.code_sigungu`
# WHERE (isMulti = True AND guLevel = True AND siLevel = False) OR (isMulti = False AND guLevel = True AND siLevel = True)
# """
# sigunguList = BH.read_table(sql)
# sigunguList = list(sigunguList['sigunguCode'])

# %%
sql = f"""
SELECT distinct sidoCode
FROM `aidepartners.aide.code_sigungu`
"""
sidoList = BH.read_table(sql)
sidoList = list(sidoList['sidoCode'])

# %%
sql =f"""
SELECT T1.*
FROM(
    SELECT sidoCode,
           complexNo, 
           complexName, 
           address,
           areaSixGroupNo, 
           pyeongNo,
           useApproveYear, 
           totalHouseholdCount, 
           tradeType, 
           jeonyongArea,
           supplyArea,
           contractDate, 
           averagePyeong, 
           averagePrice, 
           isFloor, 
           isProcessing1, 
           isProcessing2, 
           isProcessing3, 
           interpolate, 
           yearMonth, 
           isReal, 
           finalProcessing, 
           predict,
           RANK() OVER(PARTITION BY complexNo, complexName, pyeongNo ORDER BY yearMonth DESC) AS rn -- 월 구분
    FROM `aidepartners.raw.aide_apartment_price_origin`
    WHERE -- sidoCode ='28'
          -- sidoCode ='11' 
          (yearMonth >='2023-01-01' OR yearMonth <='2023-03-01')
          AND isReal = True
    ORDER BY complexNo, areaSixGRoupNo
    ) AS T1
"""
dataframe = BH.read_table(sql)

# 전달대비 하락한 지역 추론을 위한 데이터프레임 copy 및 전처리
data = dataframe.copy()
dropIdx = data[data['sidoCode'].isna()].index
data = data.drop(index = dropIdx)

# %%
# 거래가 두달 연속 있는 단지중 전달대비 하락한 단지
def findFallPrice(data):
    result = pd.DataFrame()
    for sido in sidoList:
        df = data[data['sidoCode']==sido].reset_index(drop = True)
        df_result = pd.DataFrame()
        df_pecent = pd.DataFrame({'per':[]})
        df_unique  = df[['complexNo','pyeongNo','jeonyongArea', 'supplyArea']].drop_duplicates().reset_index(drop =True)
        for i in range(0, len(df_unique)):
            cNo =df_unique['complexNo'].iloc[i]
            typeOption = df_unique['pyeongNo'].iloc[i]
            # 거래가 두달이상 연속으로 있는경우
            if len(df.loc[(df['complexNo']==cNo)&(df['pyeongNo']==typeOption), 'rn'].unique()) >1:
                # 최근거래과 과거거래 금액 차이 비교
                recentPrice = df.loc[(df['complexNo']==cNo)&(df['pyeongNo']==typeOption)&(df['rn']==1),'averagePyeong'].mean()
                pastPrice = df.loc[(df['complexNo']==cNo)&(df['pyeongNo']==typeOption)&(df['rn']==2),'averagePyeong'].mean()
                price = pastPrice - recentPrice
                per = recentPrice / pastPrice # 전달대비 현재 실거래 비율
                if (price >0)&(per<=0.85) : # 전달 거래보다 싸게거래된 경우
                    df_result = df_result.append(df[(df['complexNo']==cNo)&(df['pyeongNo']==typeOption)])
                    if i ==0:
                        df_result['per'] = ''
                    df_result.loc[(df_result['complexNo']==cNo)&(df_result['pyeongNo']==typeOption),'per'] = per

                    # 결과테이블 세팅
                    df_result = df_result[['complexNo','complexName','address','pyeongNo','jeonyongArea', 'supplyArea','per']].drop_duplicates(subset = ['complexNo','pyeongNo']).sort_values(by = 'per')
                    df_result['per'] =  round(df_result['per'], 2)

                    # 컬럼정리
                    df_report = df_result.rename(columns = {'complexName':'단지명',
                                                            'pyeongNo':'면적타입',
                                                            'address':'주소',
                                                            'jeonyongArea':'전용면적',
                                                            'supplyArea':'공급면적',
                                                            'per':'전달 대비 실거래 가격'}).reset_index(drop = True)
                    result = result.append(df_report)
    result = result.reset_index(drop = True).sort_values(by = '전달 대비 실거래 가격')
    result = result.drop_duplicates(subset = ['단지명','면적타입']).reset_index(drop = True)
    return result

# %%
result = findFallPrice(data)

# %%
df_info = result[['complexNo','면적타입']].rename(columns = {'면적타입':'pyeongNo'})
sql =f"""
SELECT T1.*
FROM(
    SELECT sidoCode,
           complexNo, 
           complexName, 
           address,
           areaSixGroupNo, 
           pyeongNo,
           useApproveYear, 
           totalHouseholdCount, 
           tradeType, 
           jeonyongArea,
           supplyArea,
           contractDate, 
           averagePyeong, 
           averagePrice, 
           isFloor, 
           isProcessing1, 
           isProcessing2, 
           isProcessing3, 
           interpolate, 
           yearMonth, 
           isReal, 
           finalProcessing, 
           predict
    FROM `aidepartners.raw.aide_apartment_price_origin`
    WHERE yearMonth >='2021-01-01' 
          AND isReal = True
          AND complexNo in {tuple(df_info['complexNo'].unique())}
    ORDER BY complexNo, areaSixGRoupNo
df_info = result[['complexNo','면적타입']].rename(columns = {'면적타입':'pyeongNo'})    ) AS T1
"""
df_new = BH.read_table(sql)

# %%
# # 최근하락한 단지의 최근2년 실거래 변동 확인
# for i in range(0, len(df_info)):
    
#     cNo = df_info['complexNo'].iloc[i]
#     pyeong = df_info['pyeongNo'].iloc[i]
    
#     # 단지-타입 특정 
#     df_unique = df_new[(df_new['complexNo']==cNo)&(df_new['pyeongNo']==pyeong)]
    
#     # 차트 제목에 사용할 파라미터 저장
#     danjiName = df_unique['complexName'].unique()
#     jeonyong = df_unique['jeonyongArea'].unique()
    
#     # 시각화
#     ## 실제값 필터
#     df_real = df_unique[df_unique['isReal']==True].reset_index(drop = True)
#     plt.figure(figsize = (12, 5))
#     sns.scatterplot(df_real['yearMonth'], df_real['averagePyeong'])
#     plt.title(f"단지명 : {danjiName}, 전용면적 : {jeonyong}")
#     plt.show()

# %% [markdown]
# # 전세가율

# %% [markdown]
# 최근주만 사용할 경우 시세가 없는단지가 있음

# %%
sql = f"""
SELECT CASE WHEN provider = 'kab' THEN max(baseYearMonthDay) END AS kab,
       CASE WHEN provider = 'kbstar' THEN max(baseYearMonthDay) END AS kbstar,
       CASE WHEN provider = 'neonet' THEN max(baseYearMonthDay) END AS neonet
        
FROM `aidepartners.aide.complex_market_price`
GROUP BY provider
"""
time = BH.read_table(sql)
time
# Out:
#           kab      kbstar      neonet
# 0  2023-03-06         NaT         NaT
# 1         NaT         NaT  2023-03-08
# 2         NaT  2023-03-10         NaT

# %%
day1 = time['kab'].dropna().iloc[0]
day2 = time['kbstar'].dropna().iloc[0]
day3 = time['neonet'].dropna().iloc[0]

# %%
day = time.iloc[0][0]

# %%
sql = f"""
SELECT danji.sidoCode,
       danji.sigunguCode,
       market.complexNo,
       danji.complexName,
       danji.sigunguName,
       detailAddress,
       market.areaNo,
       area.jeonyongArea,
       area.supplyArea,
       market.dealAveragePrice,
       market.leaseAveragePrice,
       market.leaseAveragePrice/market.dealAveragePrice AS ratio
FROM `aidepartners.aide.complex_market_price` AS market
LEFT JOIN (SELECT sidoCode,sigunguCode, complexNo, complexName, sigunguName, detailAddress FROM `aidepartners.aide.complex_danji_information`) AS danji ON market.complexNo = danji.complexNo
LEFT JOIN (SELECT complexNo, pyeongNo, jeonyongArea, supplyArea FROM `aidepartners.aide.complex_area_information_prod`) AS area ON market.complexNo =area.complexNo AND market.areaNo = area.pyeongNo
WHERE market.baseYearMonthDay = "{day}"
"""
df_ratio = BH.read_table(sql)

# %%
df_ratio[(df_ratio['sidoCode']=='11')&(-df_ratio['complexName'].str.contains('도시형'))&(-df_ratio['complexName'].str.contains('주상복합'))].sort_values(by = 'ratio',ascending = False).head(200)[['complexName','sigunguName','jeonyongArea','supplyArea','ratio']].reset_index(drop = True)
# Out:
#         complexName sigunguName  jeonyongArea  supplyArea     ratio
# 195            위더스빌    서울시 동대문구         84.99      115.19  0.683230
# 196        쌍문e-편한세상     서울시 도봉구        121.31      149.57  0.683230
# 197            위더스빌    서울시 동대문구         84.89      114.14  0.683230
# 198            위더스빌    서울시 동대문구         84.85      114.72  0.683230
# 199        남현한일유앤아이     서울시 관악구         84.99      106.62  0.683230

# %% [markdown]
# # 오피스텔 유사단지의 광역비교

# %%
sql = f"""
SELECT danji.complexNo,
       danji.complexName,
       danji.sidoCode,
       danji.sigunguCode,
       danji.bdongCode,
       danji.sigunguName,
       danji.bdongName,
       danji.totalHouseholdCount,
       danji.useApproveYear,
       danji.batlRatio,
       danji.btlRatio,
       danji.parkingPossibleCount,
       danji.parkingCountByHousehold,
       danji.HeatMethodTypeName,
       danji.HeatFuelTypeName,
       area.supplyArea,
       area.jeonyongArea,
       area.roomCount,
       area.entranceType,
       area.areaSixGroupNo,
       price.tradeType,
       price.tradeYear,
       price.tradeMonth,
       price.contractDate,
       price.dealPrice,
       price.leasePrice,
       price.rentPrice,
       price.floor
FROM `aidepartners.aide.complex_danji_information` AS danji

LEFT JOIN (
           SELECT complexNo, 
                  pyeongNo,
                  supplyArea,
                  jeonyongArea,
                  roomCount,
                  entranceType,
                  areaSixGroupNo          
           FROM `aidepartners.aide.complex_area_information_prod`
           ) AS area 
           ON danji.complexNo = area.complexNo
           
LEFT JOIN (
           SELECT complexNo, 
                  areaNo,
                  tradeType,
                  tradeYear,
                  tradeMonth,
                  contractDate,
                  dealPrice,
                  leasePrice,
                  rentPrice,
                  floor,
           FROM `aidepartners.aide.complex_real_price_prod`
           WHERE deleteYn is null
           ) AS price 
           ON area.complexNo = price.complexNo 
              AND area.pyeongNo = price.areaNo
WHERE danji.realEstateTypeCode = 'OPST' AND danji.sidoCode = '41'



"""
df = BH.read_table(sql)

# %%
# 
df[(df['sigunguCode']=='41117')&(df['bdongName']=='이의동')].sort_values(by =['complexNo','jeonyongArea'])

# %%
df[(df['sigunguCode']=='11500')&(df['bdongName']=='마곡동')].reset_index(drop = True).sort_values(by = ['complexNo','tradeYear'],ascending = False)

# %% [markdown]
# # 아파트 지역별 시세 조사

# %% [markdown]
# - type : 59/ 84
#     - 59 : A2
#     - 84 : A3
#
# - sedaeCount
#     - 300이상
#     - 2000 이상
#
# - useApproveYear
#     - new : ~ 5년
#     - general : 6년 ~ 20년
#     - old :20년 ~

# %%
sql = f"""
SELECT CASE WHEN provider = 'kab' THEN max(baseYearMonthDay) END AS kab,
       CASE WHEN provider = 'kbstar' THEN max(baseYearMonthDay) END AS kbstar,
       CASE WHEN provider = 'neonet' THEN max(baseYearMonthDay) END AS neonet
        
FROM `aidepartners.aide.complex_market_price`
GROUP BY provider
"""
time = BH.read_table(sql)
time

# %%
day1 = time['kab'].dropna().iloc[0]
day2 = time['kbstar'].dropna().iloc[0]
day3 = time['neonet'].dropna().iloc[0]

# %%
sql = f"""
SELECT danji.sidoCode,
       danji.sigunguCode,
       market.complexNo,
       danji.complexName,
       danji.sigunguName,
       detailAddress,
       market.areaNo,
       area.jeonyongArea,
       area.supplyArea,
       area.supplyPyeong,
       area.jeonyongPyeong,
       market.dealAveragePrice * 10000 AS dealAveragePrice,
       market.leaseAveragePrice * 10000 AS leaseAveragePrice,
       (market.dealAveragePrice * 10000)/ area.supplyPyeong AS dealAveragePricePerSupplyPyeong,
       (market.dealAveragePrice * 10000)/ area.jeonyongPyeong AS dealAveragePricePerJeonyongPyeong,
       market.leaseAveragePrice/market.dealAveragePrice AS ratio
       
FROM `aidepartners.aide.complex_market_price` AS market
LEFT JOIN (SELECT sidoCode,sigunguCode, complexNo, complexName, sigunguName, detailAddress FROM `aidepartners.aide.complex_danji_information`) AS danji ON market.complexNo = danji.complexNo
LEFT JOIN (SELECT complexNo, pyeongNo, jeonyongArea, supplyArea,jeonyongPyeong, supplyPyeong FROM `aidepartners.aide.complex_area_information_prod`) AS area ON market.complexNo =area.complexNo AND market.areaNo = area.pyeongNo
WHERE market.baseYearMonthDay in ("{day1}","{day2}","{day3}")
"""
df =BH.read_table(sql)

# %%
gdf = pyg.walk(df)

# %%
df[df['sidoCode']=='11'].drop_duplicates(subset = 'complexNo').reset_index(drop = True)['dealAveragePricePerSupplyPyeong'].mean()

# %%
df[(df['sidoCode']=='11')&(-df['complexName'].str.contains('도시형'))&(-df['complexName'].str.contains('주상복합'))].drop_duplicates(subset = 'complexNo').reset_index(drop = True).sort_values(by = 'ratio',ascending = False)

# %% [markdown]
# # 아파트 가격추이

# %%
startYear = datetime.now()-relative|delta(years = 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 startYear = datetime.now()-relative|delta(years = 5)
#
# NameError: name 'relative' is not defined

# %%
# class Search: 
#     """목적에 맞게 타겟을 정하는 클래스"""
    
#     def process_query(self,sido, sigungu, danji):
#         pass
    
    
# class SearchDanji(Search):
    
#     def process_query(self,sido, sigungu, danji):
#         """
#         역할 : 한개의 단지의 정보를 추출하여 해당 단지의 위치정보를 반환하는 함수
#         INPUT : 시도명, 시군구명, 단지 이름
#         OUTPUT : 시도 코드, 시군구 코드, 법정동 코드, 단지 코드
        
#         """
        
#         sql = f"""
#         SELECT complexNo,
#             complexName, 
#             sidoCode, 
#             sigunguCode,
#             bdongCode,
#             sigunguName,
#             bdongName,
#             address, 
#             detailAddress
#         FROM `aidepartners.aide.complex_danji_information`
#         WHERE sigunguName LIKE '%{sido}%' 
#               AND sigunguName LIKE '%{sigungu}%' 
#               AND complexName LIKE "%{danji}%" 
#               AND realEstateTypeName IN ('아파트','아파트분양권')
        
#         """
#         search = BH.read_table(sql)
#         sidoCode, sigunguCode, bdongCode, complexNo = search[['sidoCode','sigunguCode','bdongCode','complexNo']].iloc[0]
#         return sidoCode, sigunguCode, bdongCode, complexNo
    
# @dataclass
# class TransactionProcessing:
#     """실거래를 다양한 각도로 추출하는 클래스 입니다."""
#     sidoCode : str
#     sigunguCode : str
#     bdongCode : str
#     complexNo : str

#     def extractTargetPrice(self):
#         """입력받은 단지에 해당하는 실거래 시계열데이터 반환함수
#         OUTPUT : dataframe
#         """
#         sql = f"""
#         SELECT *
#         FROM `aidepartners.aide.aide_apartment_price_origin`
#         WHERE complexNo = "{self.complexNo}"
#         """
#         df_target = BH.read_table(sql)
#         # 날짜 형변환
#         df_target['yearMonth'] =pd.to_datetime(df_target['yearMonth'])
#         return df_target
    
#     def regionPrice(self):
#         """시도, 시군구, 법정동별 가격 추이
#         OUTPUT : 
#         """
#         # 입력단지와 같은 시도에 있는 데이터 추출
#         sql = f"""
#         SELECT *
#         FROM `aidepartners.aide.aide_apartment_price_origin`
#         WHERE sidoCode = "{self.sidoCode}"
#               AND isReal = True
#               AND yearMonth >= "2018-03-01"
#         """
#         df_total = BH.read_table(sql)
#         df_target = df_total[df_total['complexNo']==self.complexNo].sort_values(by = 'yearMonth', ascending = False).reset_index(drop =True)
#         df_sido = df_total.groupby('yearMonth')['averagePyeong'].mean().reset_index()
#         df_sigungu = df_total[df_total['sigunguCode']==self.sigunguCode].groupby('yearMonth')['averagePyeong'].mean().reset_index()
#         df_bdong = df_total[df_total['bdongCode']==self.bdongCode].groupby('yearMonth')['averagePyeong'].mean().reset_index()
#         return df_sido, df_sigungu, df_bdong, df_target, df_total
    
#     def vizAround(self):
#         """
#         특정단지의 시도, 시군구, 법정동 별 평단가 추이 시각화 
#         """
#         df_sido, df_sigungu, df_bdong, df_target, df_total = self.regionPrice()
        
#         plt.figure(figsize = (14, 5))
#         sns.scatterplot(df_sido['yearMonth'], df_sido['averagePyeong'], label = '서울')
#         sns.scatterplot(df_sigungu['yearMonth'], df_sigungu['averagePyeong'], label = '강서구')
#         sns.scatterplot(df_bdong['yearMonth'], df_bdong['averagePyeong'], label = '마곡동')

#         ## 2. y축 설정
#         current_values = plt.gca().get_yticks()
#         plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

#         ## 3. grid 설정
#         plt.grid(axis="y", c="lightgray")
#         plt.grid(axis="x", c="lightgray")

# %%
class Search: 
    """목적에 맞게 타겟을 정하는 클래스"""
    
    def searchDanji(self,sido, sigungu, danji):
        """
        
        역할 : 한개의 단지의 정보를 추출하여 해당 단지의 위치정보를 반환하는 함수
        INPUT : 시도명, 시군구명, 단지 이름
        OUTPUT : 시도 코드, 시군구 코드, 법정동 코드, 단지 코드
        
        """
        
        sql = f"""
        SELECT complexNo,
            complexName, 
            sidoCode, 
            sigunguCode,
            bdongCode,
            sigunguName,
            bdongName,
            address, 
            detailAddress
        FROM `aidepartners.aide.complex_danji_information`
        WHERE sigunguName LIKE '%{sido}%' 
              AND sigunguName LIKE '%{sigungu}%' 
              AND complexName LIKE "%{danji}%" 
              AND realEstateTypeName IN ('아파트','아파트분양권')
        
        """
        search = BH.read_table(sql)
        sidoCode, sigunguCode, bdongCode, complexNo = search[['sidoCode','sigunguCode','bdongCode','complexNo']].iloc[0]
        return sidoCode, sigunguCode, bdongCode, complexNo
    
@dataclass
class TransactionProcessing:
    """실거래를 다양한 각도로 추출하는 클래스 입니다."""
    sidoCode : str
    sigunguCode : str
    bdongCode : str
    complexNo : str

    def extractTargetPrice(self, viz = False):
        """입력받은 단지에 해당하는 실거래 시계열데이터 반환함수
        OUTPUT : dataframe
        """
        sql = f"""
        SELECT *
        FROM `aidepartners.aide.aide_apartment_price_origin`
        WHERE complexNo = "{self.complexNo}"
        """
        df_target = BH.read_table(sql)
        # 날짜 형변환
        df_target['yearMonth'] =pd.to_datetime(df_target['yearMonth'])
        
        # 시각화 결과를 원하는 경우
        if viz ==True:
            fig = plt.figure(figsize = (12, 5))
            sns.lineplot(df.loc[df['isReal']==True,'yearMonth'],df.loc[df['isReal']==True,'averagePyeong'],hue = df['areaSixGroupNo'])
            sns.scatterplot(df.loc[df['predict']==True, 'yearMonth'], df.loc[df['predict']==True, 'averagePyeong'],color = 'red')

            ## 2. y축 설정
            current_values = plt.gca().get_yticks()
            plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

            ## 3. grid 설정
            plt.grid(axis="y", c="lightgray")
            plt.grid(axis="x", c="lightgray")
            
            # 결과 이미지 객체로 저장
            graph = fig
            # 이미지 not show
            plt.close(fig)
            return df_target, graph
        
        
        return df_target
    
    def regionPrice(self):
        """시도, 시군구, 법정동별 가격 추이
        OUTPUT : 
        """
        # 입력단지와 같은 시도에 있는 데이터 추출
        sql = f"""
        SELECT *
        FROM `aidepartners.aide.aide_apartment_price_origin`
        WHERE sidoCode = "{self.sidoCode}"
              AND isReal = True
              AND yearMonth >= "2018-03-01"
        """
        df_total = BH.read_table(sql)
        df_target = df_total[df_total['complexNo']==self.complexNo].sort_values(by = 'yearMonth', ascending = False).reset_index(drop =True)
        df_sido = df_total.groupby('yearMonth')['averagePyeong'].mean().reset_index()
        df_sigungu = df_total[df_total['sigunguCode']==self.sigunguCode].groupby('yearMonth')['averagePyeong'].mean().reset_index()
        df_bdong = df_total[df_total['bdongCode']==self.bdongCode].groupby('yearMonth')['averagePyeong'].mean().reset_index()
        return df_sido, df_sigungu, df_bdong, df_target, df_total
    
    def vizAround(self):
        """
        특정단지의 시도, 시군구, 법정동 별 평단가 추이 시각화 
        """
        df_sido, df_sigungu, df_bdong, df_target, df_total = self.regionPrice()
        
        plt.figure(figsize = (14, 5))
        sns.scatterplot(df_sido['yearMonth'], df_sido['averagePyeong'], label = '서울')
        sns.scatterplot(df_sigungu['yearMonth'], df_sigungu['averagePyeong'], label = '강서구')
        sns.scatterplot(df_bdong['yearMonth'], df_bdong['averagePyeong'], label = '마곡동')

        ## 2. y축 설정
        current_values = plt.gca().get_yticks()
        plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

        ## 3. grid 설정
        plt.grid(axis="y", c="lightgray")
        plt.grid(axis="x", c="lightgray")

# %%
s = Search()
sidoCode, sigunguCode, bdongCode, complexNo = s.searchDanji('서울','마포구','올림픽파크포레온')
ap = TransactionProcessing(sidoCode = sidoCode, sigunguCode = sigunguCode, bdongCode = bdongCode, complexNo = complexNo)
df = ap.extractTargetPrice()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 s = Search()
# ----> 2 sidoCode, sigunguCode, bdongCode, complexNo = s.searchDanji('서울','마포구','올림픽파크포레온')
#       3 ap = TransactionProcessing(sidoCode = sidoCode, sigunguCode = sigunguCode, bdongCode = bdongCode, complexNo = complexNo)
#       4 df = ap.extractTargetPrice()
#
# Input In [2], in Search.searchDanji(self, sido, sigungu, danji)
#      13 sql = f"""
#      14 SELECT complexNo,
#      15     complexName,
#    (...)
#      28
#      29 """
#      30 search = BH.read_table(sql)
# ---> 31 sidoCode, sigunguCode, bdongCode, complexNo = search[['sidoCode','sigunguCode','bdongCode','complexNo']].iloc[0]
#      32 return sidoCode, sigunguCode, bdongCode, complexNo
#
# File ~\anaconda3\envs\jupyter\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\jupyter\lib\site-packages\pandas\core\indexing.py:1520, in _iLocIndexer._getitem_axis(self, key, axis)
#    1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
# -> 1520 self._validate_integer(key, axis)
#    1522 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\envs\jupyter\lib\site-packages\pandas\core\indexing.py:1452, in _iLocIndexer._validate_integer(self, key, axis)
#    1450 len_axis = len(self.obj._get_axis(axis))
#    1451 if key >= len_axis or key < -len_axis:
# -> 1452     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
graph

# %%
df['areaSixGroupNo'].unique()[0]
# Out:
# 'A2'

# %%
if len(df['areaSixGroupNo'].unique()):
    areaGroup = df['areaSixGroupNo'].unique()[0]
else:
    areaGroup = df['areaSixGroupNo']
# Out:
# 1

# %%
fig = plt.figure(figsize = (12, 5))
sns.lineplot(df.loc[df['isReal']==True,'yearMonth'],df.loc[df['isReal']==True,'averagePyeong'],hue = df['areaSixGroupNo'])
sns.scatterplot(df.loc[df['predict']==True, 'yearMonth'], df.loc[df['predict']==True, 'averagePyeong'],color = 'red')

## 2. y축 설정
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

## 3. grid 설정
plt.grid(axis="y", c="lightgray")
plt.grid(axis="x", c="lightgray")

figureTarget = fig
plt.close(fig)

# %%
ap.vizAround

# %%
class apartTimePrice():
    def __init__(self, sido, sigungu, name):
        """검색하고자 하는 시도명, 시군구명, 단지명을 입력받는다."""
        self.sido = sido
        self.sigungu = sigungu
        self.name = name

        
        
    def extractCode(self):
        """지역 코드 추출"""        
        sql = f"""
        SELECT sidoCode,
               sigunguCode,
        FROM `aidepartners.aide.code_sigungu`
        WHERE sidoName LIKE '%{self.sido}%'
              AND sigunguName LIKE '%{self.sigungu}%'
              AND ((isMulti = True AND guLevel = True AND siLevel = False) OR (isMulti = False AND guLevel = True AND siLevel = True))
        """
        code_data = BH.read_table(sql)
        if len(code_data) >1:
            raise Exception('입력받은 시도,시군구의 코드가 중복이 있습니다. 확인해 주세요') 
            
        else:
            sidoCode = code_data['sidoCode'][0]
            sigunguCode = code_data['sigunguCode'][0]
            
        return sidoCode, sigunguCode
        
        
    def extractDanjiName(self,sidoCode, sigunguCode):
        """단지 특정 및 추출"""

        sql = f"""
        SELECT complexNo, 
               complexName,
               address
        FROM `aidepartners.aide.complex_danji_information`
        WHERE sidoCode = "{sidoCode}"
              AND sigunguCode = "{sigunguCode}"
              AND complexName LIKE '%{self.name}%'        
        """
        danji_data = BH.read_table(sql)
        if len(danji_data) ==1:
            danji_data['complexNo'].iloc[0]
        
        if len(danji_data) > 1:
            print('중복되는 단지들이 있습니다. 단지를 선택해주세요')
            print('-'*130)
            print('단지목록 : ',list(danji_data['complexName'].unique()))  
            print('-'*130)
            print('주소목록 : ',list(danji_data['address'].unique()))
            print('-'*130)
            answerName = input('앞에서 출력된 단지들중 해당하는 단지를 정확하게 입력해 주세요 : ')
            answerAddress = input('앞에서 출력된 주소중 해당하는 단지의 주소를 정확하게 입력해 주세요 : ')
            cNo = danji_data.loc[(danji_data['complexName']==answerName)&(danji_data['address']==answerAddress),'complexNo'].reset_index(drop = True)[0]
       
        else:
            answerName = danji_data['complexName'].reset_index(drop = True)[0]
            cNo = danji_data.loc[danji_data['complexName']==answerName,'complexNo'][0]
            
            
        return cNo
    
    
    def extractTargetPrice(self):
        """기준단지의 시계열 가격 데이터 추출"""
        
        # 시도, 시군구 코드 추출
        sidoCode, sigunguCode = self.extractCode()
        
        # 단지명 추출
        cNo = self.extractDanjiName(sidoCode, sigunguCode)
        
    
        # 타겟 단지의 실거래 시계열데이터 프레임 추출
        """입력받은 단지에 해당하는 실거래 시계열데이터 반환함수"""
        sql = f"""
        SELECT *
        FROM `aidepartners.aide.aide_apartment_price_origin`
        WHERE complexNo = "{cNo}"
        """
        df_target = BH.read_table(sql)

        if len(df_target) == 0:
            print('단지를 찾지못했습니다.')
        else:
            bdongCode = df_target['bdongCode'].iloc[0]
            
        df_target['yearMonth'] =pd.to_datetime(df_target['yearMonth'])
        return df_target, bdongCode
    
    def recentPrice(self):
        df_target, bdongCode = self.extractTargetPrice()
        startYear = datetime.now()-relativedelta(years = 5)
        sql = f"""
        SELECT *
        FROM `aideprtners.aide.aide_apartment_price_origin`
        WHERE sidoCode LIKE '{bdongCode[:2]}%'
              AND isReal = True
              AND yearMonth >={startYear}
        """
        df_sido = BH.read_table(sql)
        
        pass
#         BH.read_table(sql)

# %%
ATP = apartTimePrice("인천", "서구", "수자인레이크")
df_target,bdongCode =ATP.extractTargetPrice()

# %%
df_target.sort_values(by = 'yearMonth',ascending = False)
# Out:
#     complexNo         complexName sidoCode sigunguCode   bdongCode     address detailAddress  \
# 111    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 34     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 101    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 194    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 96     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 72     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 151    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 149    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 5      113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 89     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 185    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 121    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 17     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 182    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 74     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 171    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 140    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 81     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 1      113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 132    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 9      113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 37     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 39     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 35     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 120    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 41     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 103    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 88     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 4      113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 94     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 107    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 23     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 26     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 80     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 196    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 100    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 18     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 164    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 66     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 146    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 50     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 83     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 117    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 143    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 172    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 178    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 176    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 12     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 116    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 189    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 29     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 84     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 77     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 21     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 15     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 161    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 137    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 92     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 60     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 199    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 102    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 131    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 126    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 16     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 205    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 51     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 59     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 75     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 25     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 118    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 6      113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 82     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 67     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 130    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 174    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 85     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 108    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 91     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 153    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 43     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 68     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 141    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 139    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 184    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 198    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 157    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 162    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 168    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 134    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 190    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 177    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 129    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 128    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 124    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 175    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 97     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 214    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 20     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 8      113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 44     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 53     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 64     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 31     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 46     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 36     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 48     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 38     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 56     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 104    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 110    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 170    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 122    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 42     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 45     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 212    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 22     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 166    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 167    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 136    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 145    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 76     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 203    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 144    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 206    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 32     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 183    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 186    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 63     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 127    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 201    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 159    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 52     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 148    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 135    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 65     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 147    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 181    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 14     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 79     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 87     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 165    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 179    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 90     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 0      113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 192    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 195    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 156    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 106    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 61     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 11     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 138    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 193    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 158    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 73     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 58     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 105    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 112    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 211    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 208    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 114    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 123    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 202    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 115    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 70     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 10     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 93     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 54     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 210    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 99     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 150    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 188    113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
# 78     113524  청라국제금융단지한양수자인레이크블루       28       28260  2826012200  인천시 서구 청라동          85-1
#
# 120           25.08             A2                     461        A1       2022          10
# 41            25.55             A3                     207        A1       2022          10
# 103           25.55             A3                     207        A1       2022          10
# 88            25.52             A5                     370        A1       2022          10
# 4             25.52             A5                     370        A1       2022           9
# 94            25.52             A3                     370        A1       2022           9
# 107           25.08             A2                     461        A1       2022           9
# 23            25.52             A5                     370        A1       2022           8
# 26            25.52             A3                     370        A1       2022           8
# 80            25.08             A2                     461        A1       2022           8
# 196           25.08             A2                     461        A1       2022           7
# 100           25.52             A5                     370        A1       2022           7
# 18            25.52             A3                     370        A1       2022           7
# 164           18.14             A2                      60        A1       2022           6
# 66            25.52             A5                     370        A1       2022           6
# 146           25.60             A3                     255        A1       2022           6
# 50            25.52             A5                     370        A1       2022           5
# 83            25.60             A3                     255        A1       2022           5
# 117           25.08             A2                     461        A1       2022           5
# 143           25.52             A3                     370        A1       2022           4
# 172           25.52             A5                     370        A1       2022           4
# 178           25.52             A3                     370        A1       2022           4
# 176           25.08             A2                     461        A1       2022           4
# 12            25.52             A3                     370        A1       2022           3
# 116           25.52             A5                     370        A1       2022           3
# 189           25.52             A3                     370        A1       2022           3
# 29            25.52             A3                     370        A1       2022           3
# 84            25.52             A3                     370        A1       2022           3
# 77            25.08             A2                     461        A1       2022           3
# 21            25.08             A2                     461        A1       2022           2
# 15            25.53             A3                     273        A1       2022           2
# 161           25.52             A5                     370        A1       2022           2
# 137           25.08             A2                     461        A1       2022           1
# 92            25.52             A3                     370        A1       2022           1
# 60            25.52             A5                     370        A1       2022           1
# 199           25.52             A5                     370        A1       2021          12
# 102           25.08             A2                     461        A1       2021          12
# 131           25.52             A3                     370        A1       2021          12
# 126           25.52             A3                     370        A1       2021          12
# 16            25.08             A2                     461        A1       2021          11
# 205           25.53             A3                     273        A1       2021          11
# 51            25.52             A5                     370        A1       2021          11
# 59            18.07             A2                      91        A1       2021          10
# 75            25.52             A5                     370        A1       2021          10
# 25            25.52             A3                     370        A1       2021          10
# 118           25.60             A3                     255        A1       2021          10
# 6             18.14             A2                      60        A1       2021           9
# 82            25.53             A3                     273        A1       2021           9
# 67            25.55             A3                     207        A1       2021           9
# 130           25.60             A3                     255        A1       2021           9
# 174           25.52             A5                     370        A1       2021           9
# 85            25.53             A3                     273        A1       2021           8
# ...
# 87        <NA>    False          False          False          False        False 2021-03-01
# 165       <NA>    False          False          False          False        False 2021-02-01
# 179       <NA>    False          False          False          False         True 2021-02-01
# 90        <NA>    False          False          False          False        False 2021-02-01
# 0         <NA>    False          False          False          False         True 2021-02-01
# 192       <NA>    False          False          False          False        False 2021-01-01
# 195       <NA>    False          False          False          False        False 2021-01-01
# 156       <NA>    False          False          False          False        False 2021-01-01
# 106       <NA>    False          False          False          False        False 2021-01-01
# 61        <NA>    False          False          False          False         True 2021-01-01
# 11        <NA>    False          False          False          False         True 2020-12-01
# 138       <NA>    False          False          False          False        False 2020-12-01
# 193       <NA>    False          False          False          False         True 2020-12-01
# 158       <NA>    False          False          False          False         True 2020-11-01
# 73        <NA>    False          False          False          False        False 2020-11-01
# 58        <NA>    False          False          False          False         True 2020-11-01
# 105       <NA>    False          False          False          False         True 2020-10-01
# 112       <NA>    False          False          False          False         True 2020-10-01
# 211       <NA>    False          False          False          False         True 2020-10-01
# 208       <NA>    False          False          False          False         True 2020-09-01
# 114       <NA>    False          False          False          False         True 2020-09-01
# 123       <NA>    False          False          False          False         True 2020-09-01
# 202       <NA>    False          False          False          False         True 2020-08-01
# 115       <NA>    False          False          False          False         True 2020-08-01
# 70        <NA>    False          False          False          False        False 2020-08-01
# 10        <NA>    False          False          False          False         True 2020-07-01
# 93        <NA>    False          False          False          False         True 2020-07-01
# 54        <NA>    False          False          False          False         True 2020-07-01
# 210       <NA>    False          False          False          False        False 2020-06-01
# 99        <NA>    False          False          False          False         True 2020-06-01
# 150       <NA>    False          False          False          False        False 2020-06-01
# 188       <NA>    False          False          False          False        False 2020-06-01
# 78        <NA>    False          False          False          False        False 2020-06-01
# 113       <NA>    False          False          False          False         True 2020-06-01
# 191       <NA>    False          False          False          False         True 2020-05-01
# 119       <NA>    False          False          False          False        False 2020-05-01
# 109       <NA>    False          False          False          False         True 2020-05-01
# 155       <NA>    False          False          False          False        False 2020-05-01
# 71        <NA>    False          False          False          False        False 2020-04-01
# 28        <NA>    False          False          False          False         True 2020-04-01
# 27        <NA>    False          False          False          False         True 2020-04-01
# 69        <NA>    False          False          False          False        False 2020-04-01
# 207       <NA>    False          False          False          False         True 2020-03-01
# 7         <NA>    False          False          False          False         True 2020-03-01
# 19        <NA>    False          False          False          False         True 2020-03-01
# 154       <NA>    False          False          False          False         True 2020-02-01
# 62          36     True          False          False          False        False 2020-02-01
# 55        <NA>    False          False          False          False         True 2020-02-01
# 163       <NA>    False          False          False          False        False 2020-02-01
# 160       <NA>    False          False          False          False         True 2020-01-01
# 209       <NA>    False          False          False          False         True 2020-01-01
# 30        <NA>    False          False          False          False         True 2020-01-01
# 204       <NA>    False          False          False          False         True 2019-12-01
# 98        <NA>    False          False          False          False         True 2019-12-01
# 40        <NA>    False          False          False          False         True 2019-12-01
# 2           36     True          False          False          False        False 2019-11-01
# 169       <NA>    False          False          False          False         True 2019-11-01
# 57        <NA>    False          False          False          False         True 2019-11-01
# 187       <NA>    False          False          False          False         True 2019-11-01
# 3         <NA>    False          False          False          False         True 2019-10-01
# 152       <NA>    False          False          False          False        False 2019-10-01
# 33        <NA>    False          False          False          False         True 2019-10-01
# 197       <NA>    False          False          False          False        False 2019-09-01
# 180       <NA>    False          False          False          False        False 2019-09-01
# 142       <NA>    False          False          False          False        False 2019-09-01
# 133       <NA>    False          False          False          False         True 2019-08-01
# 125       <NA>    False          False          False          False        False 2019-07-01
# 13        <NA>    False          False          False          False        False 2019-06-01
# 95        <NA>    False          False          False          False        False 2019-05-01
# 24        <NA>    False          False          False          False        False 2019-05-01
# 173       <NA>    False          False          False          False        False 2019-04-01
# 49        <NA>    False          False          False          False        False 2019-04-01
# 86        <NA>    False          False          False          False        False 2019-03-01
# 47        <NA>    False          False          False          False        False 2019-03-01
# 200       <NA>    False          False          False          False        False 2019-02-01
# 213       <NA>    False          False          False          False        False 2019-02-01
#
#      isReal  finalProcessing  predict
# 111   False            False     True
# 34    False            False     True
# 101   False            False     True
# 194   False            False    False
# 96    False            False    False
# 72     True            False    False
# 151    True            False    False
# 149    True            False    False
# 5      True            False    False
# 89     True            False    False
# 185    True            False    False
# 121    True            False    False
# 17    False            False    False
# 182    True            False    False
# 74     True            False    False
# 171   False            False    False
# 140    True            False    False
# 81    False            False    False
# 1      True            False    False
# 132   False            False    False
# 9      True            False    False
# 37     True            False    False
# 39     True            False    False
# 35     True            False    False
# 120   False            False    False
# 41     True            False    False
# 103   False            False    False
# 88    False            False    False
# 4     False            False    False
# 94    False            False    False
# 107   False            False    False
# 23    False            False    False
# 26    False            False    False
# 80    False            False    False
# 196   False            False    False
# 100   False            False    False
# 18    False            False    False
# 164    True            False    False
# 66    False            False    False
# 146    True            False    False
# 50    False            False    False
# 83     True            False    False
# 117   False            False    False
# 143   False            False    False
# 172   False            False    False
# 178   False            False    False
# 176   False            False    False
# 12    False            False    False
# 116   False            False    False
# 189   False            False    False
# 29    False            False    False
# 84    False            False    False
# 77    False            False    False
# 21    False            False    False
# 15     True            False    False
# 161   False            False    False
# 137   False            False    False
# 92    False            False    False
# 60    False            False    False
# 199   False            False    False
# 102   False            False    False
# 131   False            False    False
# 126   False            False    False
# 16    False            False    False
# 205    True            False    False
# 51    False            False    False
# 59     True            False    False
# 75    False            False    False
# 25     True            False    False
# 118    True            False    False
# 6      True            False    False
# 82     True            False    False
# 67     True            False    False
# 130   False            False    False
# 174   False            False    False
# 85     True            False    False
# 108    True            False    False
# 91    False            False    False
# 153    True            False    False
# 43     True            False    False
# 68    False            False    False
# 141    True            False    False
# 139   False            False    False
# 184    True            False    False
# 198    True            False    False
# 157    True            False    False
# 162    True            False    False
# 168    True            False    False
# 134    True            False    False
# 190    True            False    False
# 177   False            False    False
# 129   False            False    False
# 128    True            False    False
# 124    True            False    False
# 175   False            False    False
# 97     True            False    False
# 214   False            False    False
# 20    False            False    False
# 8      True            False    False
# 44     True            False    False
# 53    False            False    False
# 64     True            False    False
# 31     True            False    False
# 46     True            False    False
# 36     True            False    False
# 48     True            False    False
# 38     True            False    False
# 56     True            False    False
# 104    True            False    False
# 110    True            False    False
# 170   False            False    False
# 122   False            False    False
# 42     True            False    False
# 45     True            False    False
# 212    True            False    False
# 22     True            False    False
# 166   False            False    False
# 167   False            False    False
# 136    True            False    False
# 145    True            False    False
# 76    False            False    False
# 203    True            False    False
# 144    True            False    False
# 206    True            False    False
# 32     True            False    False
# 183    True            False    False
# 186   False            False    False
# 63    False            False    False
# 127    True            False    False
# 201   False            False    False
# 159    True            False    False
# 52     True            False    False
# 148    True            False    False
# 135   False            False    False
# 65     True            False    False
# 147    True            False    False
# 181    True            False    False
# 14    False            False    False
# 79    False            False    False
# 87     True            False    False
# 165    True            False    False
# 179   False            False    False
# 90     True            False    False
# 0     False            False    False
# 192    True            False    False
# 195    True            False    False
# 156    True            False    False
# 106    True            False    False
# 61    False            False    False
# 11    False            False    False
# 138    True            False    False
# 193   False            False    False
# 158   False            False    False
# 73     True            False    False
# 58    False            False    False
# 105   False            False    False
# 112   False            False    False
# 211   False            False    False
# 208   False            False    False
# 114   False            False    False
# 123   False            False    False
# 202   False            False    False
# 115   False            False    False
# 70     True            False    False
# 10    False            False    False
# 93    False            False    False
# 54    False            False    False
# 210    True            False    False
# 99    False            False    False
# 150    True            False    False
# 188    True            False    False
# 78     True            False    False
# 113   False            False    False
# 191   False            False    False
# 119    True            False    False
# 109   False            False    False
# 155    True            False    False
# 71     True            False    False
# 28    False            False    False
# 27    False            False    False
# 69     True            False    False
# 207   False            False    False
# 7     False            False    False
# 19    False            False    False
# 154   False            False    False
# 62    False            False    False
# 55    False            False    False
# 163    True            False    False
# 160   False            False    False
# 209   False            False    False
# 30    False            False    False
# 204   False            False    False
# 98    False            False    False
# 40    False            False    False
# 2     False            False    False
# 169   False            False    False
# 57    False            False    False
# 187   False            False    False
# 3     False            False    False
# 152    True            False    False
# 33    False            False    False
# 197    True            False    False
# 180    True            False    False
# 142    True            False    False
# 133   False            False    False
# 125    True            False    False
# 13     True            False    False
# 95     True            False    False
# 24     True            False    False
# 173    True            False    False
# 49     True            False    False
# 86     True            False    False
# 47     True            False    False
# 200    True            False    False
# 213    True            False    False

# %%
sql = f"""
SELECT *
FROM `aidepartners.aide.aide_apartment_price_origin`
WHERE sidoCode LIKE '11%'
      AND isReal = True
      AND yearMonth >='2018-03-01'
"""
df_sido = BH.read_table(sql)

# %%
test = df_sido.groupby('yearMonth')['averagePyeong'].mean().reset_index()
test2 = df_sido[df_sido['sigunguCode']=='11500'].groupby('yearMonth')['averagePyeong'].mean().reset_index()
test3 = df_sido[df_sido['bdongCode']=='1150010500'].groupby('yearMonth')['averagePyeong'].mean().reset_index()
test4 = df_sido[df_sido['sigunguCode']=='11710'].groupby('yearMonth')['averagePyeong'].mean().reset_index()
test5 = df_sido[df_sido['bdongCode']=='1171010100'].groupby('yearMonth')['averagePyeong'].mean().reset_index()

# %%
df_target[(df_target['isReal']==True)&(df_target['yearMonth']>='2020-01-01')].sort_values(by ='yearMonth')
# Out:
#      complexNo complexName sidoCode sigunguCode   bdongCode      address detailAddress  \
# 467        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 459        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 586        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 180        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 28         410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 383        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 769        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 109        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 526        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 580        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 201        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 240        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 597        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 558        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 236        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 614        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 420        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 443        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 372        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 492        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 659        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 209        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 648        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 489        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1667       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1664       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1665       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1677       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1676       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1675       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1666       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1674       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1668       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1669       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1673       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1672       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1671       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1670       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1832       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1838       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1827       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1831       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1834       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1835       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1836       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1828       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1824       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1837       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1833       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1825       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1842       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1829       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1840       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1841       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1830       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1826       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 1839       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 150        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 677        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 288        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 81         410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 540        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 178        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 680        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 639        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 437        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 326        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 374        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 160        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 579        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 142        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 408        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 464        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 550        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 286        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 627        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 612        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 516        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 687        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 395        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 4          410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 229        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 156        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 130        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 145        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 487        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 154        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 12         410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 65         410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 202        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 538        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 551        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 167        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2135       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2136       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2134       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2138       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2140       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2141       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2142       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2143       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2137       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2139       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2145       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2129       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2144       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2133       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2132       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2131       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2130       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2127       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 2128       410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 323        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 124        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 782        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 808        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 605        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 496        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 463        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
# 141        410        성산시영       11       11440  1144012500  서울시 마포구 성산동           446
#
# 281        <NA>    False          False          False          False        False 2022-02-01
# 359        <NA>    False          False          False          False        False 2022-03-01
# 595        <NA>    False          False          False          False        False 2022-03-01
# 230        <NA>    False          False          False          False        False 2022-03-01
# 414        <NA>    False          False          False          False        False 2022-03-01
# 524        <NA>    False          False          False          False        False 2022-03-01
# 364        <NA>    False          False          False          False        False 2022-03-01
# 67         <NA>    False          False          False          False        False 2022-04-01
# 436        <NA>    False          False          False          False        False 2022-04-01
# 1          <NA>    False          False          False          False        False 2022-04-01
# 517        <NA>    False          False          False          False        False 2022-04-01
# 431        <NA>    False          False          False          False        False 2022-05-01
# 54         <NA>    False          False          False          False        False 2022-05-01
# 567        <NA>    False          False          False          False        False 2022-05-01
# 371        <NA>    False          False          False          False        False 2022-05-01
# 685        <NA>    False          False          False          False        False 2022-06-01
# 630        <NA>    False          False          False          False        False 2022-06-01
# 488        <NA>    False          False          False          False        False 2022-06-01
# 804        <NA>    False          False          False          False        False 2022-06-01
# 171        <NA>    False          False          False          False        False 2022-06-01
# 594        <NA>    False          False          False          False        False 2022-07-01
# 561        <NA>    False          False          False          False        False 2022-10-01
# 537        <NA>    False          False          False          False        False 2022-11-01
# 97         <NA>    False          False          False          False        False 2022-11-01
# 342        <NA>    False          False          False          False        False 2022-11-01
# 798        <NA>    False          False          False          False        False 2022-12-01
# 422        <NA>    False          False          False          False        False 2023-01-01
# 543        <NA>    False          False          False          False        False 2023-01-01
# 246        <NA>    False          False          False          False        False 2023-01-01
# 446        <NA>    False          False          False          False        False 2023-01-01
# 598        <NA>    False          False          False          False        False 2023-01-01
# 179        <NA>    False          False          False          False        False 2023-01-01
# 205        <NA>    False          False          False          False        False 2023-02-01
# 756        <NA>    False          False          False          False        False 2023-02-01
# 727        <NA>    False          False          False          False        False 2023-02-01
# 504        <NA>    False          False          False          False        False 2023-02-01
# 434        <NA>    False          False          False          False        False 2023-02-01
#
#       isReal  finalProcessing  predict
# 467     True            False    False
# 459     True            False    False
# 586     True            False    False
# 180     True            False    False
# 28      True            False    False
# 383     True            False    False
# 769     True            False    False
# 109     True            False    False
# 526     True            False    False
# 580     True            False    False
# 201     True            False    False
# 240     True            False    False
# 597     True            False    False
# 558     True            False    False
# 236     True            False    False
# 614     True            False    False
# 420     True            False    False
# 443     True            False    False
# 372     True            False    False
# 492     True            False    False
# 659     True            False    False
# 209     True            False    False
# 648     True            False    False
# 489     True            False    False
# 1667    True            False    False
# 1664    True            False    False
# 1665    True            False    False
# 1677    True            False    False
# 1676    True            False    False
# 1675    True            False    False
# 1666    True            False    False
# 1674    True            False    False
# 1668    True            False    False
# 1669    True            False    False
# 1673    True            False    False
# 1672    True            False    False
# 1671    True            False    False
# 1670    True            False    False
# 1832    True            False    False
# 1838    True            False    False
# 1827    True            False    False
# 1831    True            False    False
# 1834    True            False    False
# 1835    True            False    False
# 1836    True            False    False
# 1828    True            False    False
# 1824    True            False    False
# 1837    True            False    False
# 1833    True            False    False
# 1825    True            False    False
# 1842    True            False    False
# 1829    True            False    False
# 1840    True            False    False
# 1841    True            False    False
# 1830    True            False    False
# 1826    True            False    False
# 1839    True            False    False
# 150     True            False    False
# 677     True            False    False
# 288     True            False    False
# 81      True            False    False
# 540     True            False    False
# 178     True            False    False
# 680     True            False    False
# 639     True            False    False
# 437     True            False    False
# 326     True            False    False
# 374     True            False    False
# 160     True            False    False
# 579     True            False    False
# 142     True            False    False
# 408     True            False    False
# 464     True            False    False
# 550     True            False    False
# 286     True            False    False
# 627     True            False    False
# 612     True            False    False
# 516     True            False    False
# 687     True            False    False
# 395     True            False    False
# 4       True            False    False
# 229     True            False    False
# 156     True            False    False
# 130     True            False    False
# 145     True            False    False
# 487     True            False    False
# 154     True            False    False
# 12      True            False    False
# 65      True            False    False
# 202     True            False    False
# 538     True            False    False
# 551     True            False    False
# 167     True            False    False
# 2135    True            False    False
# 2136    True            False    False
# 2134    True            False    False
# 2138    True            False    False
# 2140    True            False    False
# 2141    True            False    False
# 2142    True            False    False
# 2143    True            False    False
# 2137    True            False    False
# 2139    True            False    False
# 2145    True            False    False
# 2129    True            False    False
# 2144    True            False    False
# 2133    True            False    False
# 2132    True            False    False
# 2131    True            False    False
# 2130    True            False    False
# 2127    True            False    False
# 2128    True            False    False
# 323     True            False    False
# 124     True            False    False
# 782     True            False    False
# 808     True            False    False
# 605     True            False    False
# 496     True            False    False
# 463     True            False    False
# 141     True            False    False
# 470     True            False    False
# 212     True            False    False
# 751     True            False    False
# 17      True            False    False
# 638     True            False    False
# 75      True            False    False
# 257     True            False    False
# 569     True            False    False
# 793     True            False    False
# 566     True            False    False
# 644     True            False    False
# 187     True            False    False
# 625     True            False    False
# 87      True            False    False
# 139     True            False    False
# 599     True            False    False
# 29      True            False    False
# 108     True            False    False
# 572     True            False    False
# 770     True            False    False
# 613     True            False    False
# 611     True            False    False
# 574     True            False    False
# 465     True            False    False
# 601     True            False    False
# 693     True            False    False
# 304     True            False    False
# 263     True            False    False
# 588     True            False    False
# 623     True            False    False
# 199     True            False    False
# 666     True            False    False
# 110     True            False    False
# 82      True            False    False
# 738     True            False    False
# 8       True            False    False
# 649     True            False    False
# 302     True            False    False
# 157     True            False    False
# 244     True            False    False
# 334     True            False    False
# 658     True            False    False
# 281     True            False    False
# 359     True            False    False
# 595     True            False    False
# 230     True            False    False
# 414     True            False    False
# 524     True            False    False
# 364     True            False    False
# 67      True            False    False
# 436     True            False    False
# 1       True            False    False
# 517     True            False    False
# 431     True            False    False
# 54      True            False    False
# 567     True            False    False
# 371     True            False    False
# 685     True            False    False
# 630     True            False    False
# 488     True            False    False
# 804     True            False    False
# 171     True            False    False
# 594     True            False    False
# 561     True            False    False
# 537     True            False    False
# 97      True            False    False
# 342     True            False    False
# 798     True            False    False
# 422     True            False    False
# 543     True            False    False
# 246     True            False    False
# 446     True            False    False
# 598     True            False    False
# 179     True            False    False
# 205     True            False    False
# 756     True            False    False
# 727     True            False    False
# 504     True            False    False
# 434     True            False    False

# %%
plt.figure(figsize = (14, 5))
sns.lineplot(test['yearMonth'], test['averagePyeong'], label = '서울')
sns.lineplot(test2['yearMonth'], test2['averagePyeong'], label = '강서구')
sns.lineplot(test3['yearMonth'], test3['averagePyeong'], label = '마곡동')
# sns.scatterplot(df_target.loc[((df_target['isReal']==True)|(df_target['predict']==True)|(df_target['predict']==True))&(df_target['yearMonth']>='2018-03-01')&(df_target['areaSixGroupNo']=='A3'),'yearMonth'], df_target.loc[((df_target['isReal']==True)|(df_target['predict']==True))&(df_target['yearMonth']>='2018-03-01')&(df_target['areaSixGroupNo']=='A3'),'averagePyeong'],label = '엠밸리7단지')
# Out:
# <AxesSubplot:xlabel='yearMonth', ylabel='averagePyeong'>

# %%
from dataclasses import dataclass

class FeasibilityTest():
    def __init__(self, sidoName, sigunguName, bdongName, danjiName):
        self.sidoName = sidoName
        self.sigunguName = sigunguName
        self.bdongName = bdongName
        self.danjiName = danjiName 
        
    def duplicateTest(self):
        """단지명 중복여부 및 오입력 확인 및 코드추출 -> 추후에 데코레이터로 생성"""
        sql = f"""
        SELECT sidoCode, sigunguCode, bdongCode, complexNo
        FROM `aidepartners.aide.complex_danji_information`
        WHERE sigunguName LIKE "%{self.sidoName}%"
              AND sigunguName LIKE "%{self.sigunguName}%"
              AND bdongName LIKE "%{self.bdongName}%"
              AND complexName = "{self.danjiName}"
        """
        dupl = BH.read_table(sql)

        # 중복검증
        if len(dupl)!= 1:
            raise Exception('동일한 단지명으로 중복이 있습니다.')
        else:
            sidoCode, sigunguCode, bdongCode, complexNo = dupl.iloc[0]
            return sidoCode, sigunguCode, bdongCode, complexNo
    
    def regionData(self, sidoCode, sigunguCode, bdongCode, complexNo):
        """입력 단지에 해당하는 지역별 데이터 프레임 생성"""
        sql =f"""
        SELECT *
        FROM `aidepartners.aide.aide_apartment_price_origin`
        WHERE yearMonth >= '2018-01-01'
              AND sidoCode = '{sidoCode}'
              AND ((isReal = True) or (predict = True))
        """
        # 시도
        df = BH.read_table(sql)
        # 입력단지
        df_danji = df[df['complexNo']==complexNo].reset_index(drop = True)
        return df, df_danji
    
    def danjiPrice(self, df_danji):
        """입력단지의 면적 그룹별 가격추이"""
        
        # 면적그룹 리스트
        areaList = list(df_danji['areaSixGroupNo'].unique())
        
        # viz
        fig = plt.figure(figsize = (14, 5))
        sns.lineplot(df_danji['yearMonth'], df_danji['averagePyeong'], hue = df_danji['areaSixGroupNo'])
        
        # y축 설정
        current_values =plt.gca().get_yticks()
        plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
        
        # grid 설정
        plt.grid(axis = "y", c = "lightgray")
        plt.grid(axis = "x", c = "lightgray")
        
        # 결과 이미지 객체로 저장
        graph = fig
        
        # 이미지 not show
        plt.close(fig)
        return fig
    
    def regionPrice(self, df):
        """시도, 시군구, 법정동 평당가 평균의 추이"""
        df[df['isReal']==True].groupby('yearMonth')['averagePyeong'].mean()

# %%
FT = FeasibilityTest(sidoName = '서울', sigunguName = '강서구', bdongName = '마곡동', danjiName = '마곡엠밸리7단지')
sidoCode, sigunguCode, bdongCode, complexNo = FT.duplicateTest()
df, df_danji = FT.regionData(sidoCode, sigunguCode, bdongCode, complexNo)
fig = FT.danjiPrice(df_danji)

# %%
fig
